# %%
import numpy as np
import pandas as pd
from os import path
import pickle

pd.options.display.max_seq_items = 2000

# %%
openfile=open( r"C:\Users\Joseph\Documents\Beamly\TakeHomeTask\beamly_case_study2.pickle", "rb")
df=pickle.load(openfile)
openfile.close()

# %%
df.shape
# Out:
# (27091, 13)

# %%
df.columns
# Out:
# Index(['date', 'avg_hour', 'min_hour', 'max_hour', 'device_name',
#        'productBand', 'avg_price', 'total_products', 'num_orders', 'city',
#        'region', 'County', 'Country'],
#       dtype='object')

# %%
df.head(20)
# Out:
#           date  avg_hour  min_hour  max_hour         device_name  \
# 1   2018-07-12      20.0        20        20              Mobile
# 2   2018-08-05      22.0        22        22  Desktop and Laptop
# 3   2018-07-13      14.0        14        14              Mobile
# 5   2018-08-10      19.0        19        19              Tablet
# 6   2018-07-12      17.0        17        17  Desktop and Laptop
# 7   2018-07-09      16.0        16        16              Mobile
# 8   2018-07-05      11.0        11        11  Desktop and Laptop
# 10  2018-08-07      18.0        18        18  Desktop and Laptop
# 11  2018-08-11      12.0        12        12  Desktop and Laptop
# 12  2018-07-17      12.5        11        14              Tablet
# 13  2018-07-16      13.0        13        13              Mobile
# 16  2018-08-13      15.0        15        15              Mobile
# 17  2018-07-12      15.0        15        15  Desktop and Laptop
# 19  2018-07-10      16.0        16        16              Mobile
# 20  2018-08-11      15.0        15        15              Mobile
# 21  2018-07-06       6.0         6         6  Desktop and Laptop
# 22  2018-07-09      15.0        15        15              Mobile
# 23  2018-08-06      19.0        19        19  Desktop and Laptop
# 24  2018-07-15      22.0        22        22              Mobile
# 25  2018-07-29      12.5         2        23              Mobile
#
#        productBand  avg_price  total_products  num_orders       city  \
# 1   between20and30     29.950             1.0           1   Redbourn
# 2   between20and30     27.950             1.0           1   Bearsden
# 3   between20and30     27.950             1.0           1   Bearsden
# 5       lessThan10      9.950             1.0           1   Bearsden
# 6   between20and30     29.950             1.0           1  Greenwich
# 7   between20and30     29.950             1.0           1  Greenwich
# 8       lessThan10      8.990             1.0           1  Greenwich
# 10      lessThan10      1.990             4.0           1  Greenwich
# 11  between10and20     19.950             1.0           1  Greenwich
# 12  between20and30     26.225             2.0           2  Greenwich
# 13  between10and20     14.950             1.0           1  Greenwich
# 16  between10and20     19.900             NaN           1  Greenwich
# 17      lessThan10      1.500             1.0           1  Greenwich
# 19  between10and20     19.950             2.0           1  Greenwich
# 20  between20and30     22.950             NaN           1  Greenwich
# 21  between10and20     14.950             1.0           1  Greenwich
# 22      lessThan10      1.950             5.0           1  Greenwich
# 23      lessThan10      2.160             4.0           1  Greenwich
# 24   price_missing        NaN             1.0           1  Greenwich
# 25  between20and30     25.950             2.0           2  Greenwich
#
#                  region         County  Country
# 1         Hertfordshire  Hertfordshire  England
# 2   East Dunbartonshire            NaN      NaN
# 3   East Dunbartonshire            NaN      NaN
# 5   East Dunbartonshire            NaN      NaN
# 6             Greenwich            NaN      NaN
# 7             Greenwich            NaN      NaN
# 8             Greenwich            NaN      NaN
# 10            Greenwich            NaN      NaN
# 11            Greenwich            NaN      NaN
# 12            Greenwich            NaN      NaN
# 13            Greenwich            NaN      NaN
# 16            Greenwich            NaN      NaN
# 17            Greenwich            NaN      NaN
# 19            Greenwich            NaN      NaN
# 20            Greenwich            NaN      NaN
# 21            Greenwich            NaN      NaN
# 22            Greenwich            NaN      NaN
# 23            Greenwich            NaN      NaN
# 24            Greenwich            NaN      NaN
# 25            Greenwich            NaN      NaN

# %% [markdown]
# #### Note on Nans
#
# Nans exist in the following columns and need to be imputed: avg_price, total_products, County, Country

# %% [markdown]
#  Start with something 'easy' or not too important. Want to think about how could impute Country/County, so look to see if city or region can help.

# %% [markdown]
# ### Impute Country/County

# %%
df.groupby(['Country'])['County'].unique().to_dict()
# Out:
# {'England': array(['Hertfordshire', 'Suffolk', 'Worcestershire', 'West Sussex',
#         'Lincolnshire', 'Essex', 'North Yorkshire', 'Cornwall', 'Devon',
#         'Norfolk', 'Hampshire', 'Buckinghamshire', 'Nottinghamshire',
#         'East Sussex', 'Kent', 'Lancashire', 'Staffordshire', 'Bristol',
#         'Surrey', 'Cumbria', 'Northumberland', 'Derbyshire',
#         'Northamptonshire', 'Gloucestershire', 'Cambridgeshire',
#         'Oxfordshire', 'Warwickshire', 'Somerset', 'Wiltshire', 'Dorset',
#         'Shropshire', 'Bedfordshire', 'Leicestershire', 'Herefordshire',
#         'Rutland'], dtype=object),
#  'Scotland': array(['Falkirk', 'East Lothian', 'Fife', 'Clackmannanshire', 'Moray',
#         'West Lothian', 'Scottish Borders', 'Aberdeenshire', 'Angus'],
#        dtype=object),
#  'Wales': array(['Pembrokeshire', 'Conwy', 'Monmouthshire', 'Carmarthenshire',
#         'Gwynedd', 'Denbighshire', 'Ceredigion', 'Wrexham', 'Flintshire',
#         'Powys'], dtype=object)}

# %%
country_city_dict=df.groupby(['Country'])['city'].unique().to_dict()
for i in country_city_dict['England']:
    if i=='Greenwich':
        print(i)

# %% [markdown]
# Was thinking of using the city and region to impute a county and country, but looks like that won't work. It's probably easiest to make a new generalised Country as UK, for the sake of this excerise it would be easier. Otherwise you could use an outside source of information to match cities with county and country.

# %% [markdown]
# I think the easiest thing to do now would be to replace the missing fields with missing_country and missing_county. Especially as it is not relevant to the problem, which is just to forecast sales no specific to country or county.
